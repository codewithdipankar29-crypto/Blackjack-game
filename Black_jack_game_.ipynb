# %% [markdown]
# <a href="https://colab.research.google.com/github/codewithdipankar29-crypto/Blackjack-game/blob/main/Black_jack_game_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
card_categories = ["hearts","diamonds","clubs","spades"]
cards_list = ['ace''2','3','4','5','6','7','8','9','10','jack','queen','king']
deck = [(card,category) for category in card_categories for card in cards_list]
def card_value(card):
  if card[0] in ['jack','queen','king']:
    return 10
  elif card[0] == 'ace':
    return 11
  else:
      return int(card[0])

# %%
import random

random.shuffle(deck)

player_card = [deck.pop(), deck.pop()]
dealer_card = [deck.pop(), deck.pop()]

while True:
    player_score = sum(card_value(card) for card in player_card)
    dealer_score = sum(card_value(card) for card in dealer_card)

    print("Cards player has:", player_card)
    print("Score of the player:", player_score)
    print("\n")

    choice = input('What do you want to do? (type "play" to draw another card or "stop" to stand): ')

    if choice == 'play':
        new_card = deck.pop()
        player_card.append(new_card)

    elif choice == "stop":
        print("Cards dealer has:", dealer_card)
        print("Score of the dealer:", dealer_score)
        break

    else:
        print("Invalid choice. Please type 'play' or 'stop'.")
# Out:
# Cards player has: [('4', 'hearts'), ('jack', 'clubs')]
# Score of the player: 14
#
#
# What do you want to do? (type "play" to draw another card or "stop" to stand): stop
# Cards dealer has: [('3', 'hearts'), ('king', 'diamonds')]
# Score of the dealer: 13

# %%
#dealer has to draw cards now
while dealer_score < 17:
    new_card = deck.pop()
    dealer_card.append(new_card)
    dealer_score += card_value(new_card)

print("Cards Dealer Has:", dealer_card)
print("Score Of The Dealer:", dealer_score)
print("\n")
# Out:
# Cards Dealer Has: [('3', 'hearts'), ('king', 'diamonds'), ('7', 'spades')]
# Score Of The Dealer: 20

# %%
#decision wala code hai ye omggg who will win guess karna
if dealer_score > 21:
    print("Cards Dealer Has:", dealer_card)
    print("Score Of The Dealer:", dealer_score)
    print("Cards Player Has:", player_card)
    print("Score Of The Player:", player_score)
    print("Player wins (Dealer Loss Because Dealer Score is exceeding 21)")
elif player_score > dealer_score:
    print("Cards Dealer Has:", dealer_card)
    print("Score Of The Dealer:", dealer_score)
    print("Cards Player Has:", player_card)
    print("Score Of The Player:", player_score)
    print("Player wins (Player Has High Score than Dealer)")
elif dealer_score > player_score:
    print("Cards Dealer Has:", dealer_card)
    print("Score Of The Dealer:", dealer_score)
    print("Cards Player Has:", player_card)
    print("Score Of The Player:", player_score)
    print("Dealer wins (Dealer Has High Score than Player)")
else:
    print("Cards Dealer Has:", dealer_card)
    print("Score Of The Dealer:", dealer_score)
    print("Cards Player Has:", player_card)
    print("Score Of The Player:", player_score)
    print("It's a tie.")
# Out:
# Cards Dealer Has: [('3', 'hearts'), ('king', 'diamonds'), ('7', 'spades')]
# Score Of The Dealer: 20
# Cards Player Has: [('4', 'hearts'), ('jack', 'clubs')]
# Score Of The Player: 14
# Dealer wins (Dealer Has High Score than Player)
